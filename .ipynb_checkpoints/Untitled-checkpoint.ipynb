# %%
from seleniumwire import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import numpy as np
import cv2
from matplotlib import pyplot as plt
import time
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options

import signal
from contextlib import contextmanager
import monkey
import os
from twocaptcha import TwoCaptcha
import random 
class TimeoutException(Exception): pass

@contextmanager
def time_limit(seconds):
    def signal_handler(signum, frame):
        raise TimeoutException("Timed out!")
    signal.signal(signal.SIGALRM, signal_handler)
    signal.alarm(seconds)
    try:
        yield
    finally:
        signal.alarm(0)

# %%
row = {}
row['username'] = 'warproxxx13@gmail.com'
row['password'] = 'm@$pU52A%J3u7C'
row['withdraw'] = '0xDF2f2cda0110fB8424EAc1239AfA00Ab9976c9d9'

profile_dir = 'profiles/' + row['username'].split('@')[0]

if not os.path.isdir(profile_dir + "/Default"):
    os.makedirs(profile_dir + "/Default")

options = webdriver.ChromeOptions()
options.add_argument("user-data-dir=" + profile_dir)

# %%
solver = TwoCaptcha('85a9bd82da66dba138da2596e644cacd')

# %%
driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=options)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
# Driver [/Users/warproxxx/.wdm/drivers/chromedriver/mac64/97.0.4692.71/chromedriver] found in cache

# %%
def get_top_text():
    return driver.find_element_by_tag_name('nav').text

def get_bottom_text():
    try:
        return driver.find_elements_by_id('panel')[-1].text
    except:
        try:
            return driver.find_elements_by_id('root')[-1].text
        except:
            ""
            
    return bottom

def get_left_text():
    return driver.find_element_by_id('left-col').text

def spin():
    left_text = get_left_text()
    
    if 'Spin your boxes?' in get_left_text():
        driver.get('https://cryptoroyale.one/wheel.html')
        time.sleep(.5)
        WebDriverWait(driver, 20).until(EC.presence_of_element_located((By.XPATH, "//button[contains(.,'Feed')]"))).click()
        
        try:
            target = int(driver.find_element_by_tag_name('li').text.split('\n')[-1].split(' ')[-1])
        except:
            target = 0
            
    
        if target >= 100:
            WebDriverWait(driver, 20).until(EC.presence_of_element_located((By.XPATH, "//button[contains(.,'Spin')]"))).click()
            time.sleep(4)
        
        driver.get('https://cryptoroyale.one/ranked')
        
def move_mouse(target_x, target_y, click=False):
    try:
        game_board_element = driver.find_element_by_tag_name('canvas')
        action_chains = ActionChains(driver)
        action_chains.move_to_element_with_offset(game_board_element, target_x, target_y)
        
        if click == True:
            print('clicking')
            action_chains.click()
            
        action_chains.perform()
    except:
        pass

# %%
def perform_login(row):
    while True:
        try:
            driver.get('https://cryptoroyale.one/ranked')

            try:
                WebDriverWait(driver, 20).until(EC.presence_of_element_located((By.PARTIAL_LINK_TEXT, "Discord"))).click()
            except:
                try:
                    WebDriverWait(driver, 20).until(EC.presence_of_element_located((By.XPATH, "//button[contains(.,'Play')]")))
                    return
                except:
                    perform_login()
            
            driver.switch_to.window(driver.window_handles[1])
            WebDriverWait(driver, 20).until(EC.presence_of_element_located((By.NAME, "email")))
            elem = driver.find_element_by_name('email')
            elem.send_keys(row['username'])
            driver.find_element_by_name('password').send_keys(row['password'])
            driver.find_element_by_name('password').send_keys(Keys.ENTER)

            while True:
                try:
                    driver.find_element_by_xpath('//button[2]/div').click()
                    break
                except:
                    pass

            time.sleep(2)

            if 'linked' not in driver.find_element_by_tag_name('body').text:
                perform_login()

            driver.close()
            driver.switch_to.window(driver.window_handles[0])
            driver.get('https://cryptoroyale.one/ranked')
            break
        except:
            pass

# %%
def get_players():
    user_state = driver.execute_script("return window.user_state")
    player_id = user_state['cloud']['pid']
    game_state = driver.execute_script("return window.game_state")
    players = parse_players(game_state)
    
    try:
        player_self = [p for p in players if str(p["ID"]) == str(player_id)][0]
    except:
        print("Self not found")
        player_self = []
        
    return players, player_self

def parse_players(player):
    
    
    def parse_player(player,pid):
        try:
            return {
                "ID": pid,
                "HP": player["HP"],
                "alive": player["HP"] > 3,
                "class": player["class"],
                "place": player["place"],
                "position_x": player.get("pos", {}).get("x", 0),
                "position_y": player.get("pos", {}).get("y", 0),
                "to_x": player.get("to", {}).get("x", 0),
                "to_y": player.get("to", {}).get("y", 0),
                "inertia_x": player.get("inertia_x", {}).get("x", 0),
                "inertia_y": player.get("inertia_y", {}).get("y", 0),
                "error": False
            }
        except:
            return {
                "ID": pid,
                "error": True
            }

    return [parse_player(player["players"][pid],pid) for pid in player["players"]]

class Players:
    def __init__(self):
        #P = Blue, R = Pink, S = Yellow
        self.RULES = {'P': 'R', 'R': 'S', 'S': 'P'}
        self.update_players()
    
    def update_players(self):
        self.players, _ = get_players()
        
        if len(_) > 2:
            self.player_self = _
        
    def get_player_by_id(self, t):
        self.update_players()        
        curr = self.players[t]
        priori = 0
        
        if curr['class'] != self.RULES[self.player_self['class']]:
            priori = 1
            
        return curr, priori
    
    def check_color_exist(self):
        self.update_players()
        
    def get_target_idx(self):
        self.update_players()

        for i in range(len(self.players)):
            curr = self.players[i]
            
            if 'class' in curr and 'class' in self.player_self:
                if (curr['class'] == self.RULES[self.player_self['class']] and curr['HP'] > 0) or (curr['class'] == self.player_self['class'] and curr['HP'] < self.player_self['HP']):
                    return curr, i, 0

        return {}, 0, 2

# %%
def play_again():
    while True:
        try:
            driver.find_element_by_xpath("//button[contains(.,'Play')]").click()
            time.sleep(.5)
            
            try:
                driver.find_element_by_xpath("//button[contains(.,'Play')]").click()
            except:
                pass
            
            break
        except:
            time.sleep(.1)

    while 'HP' not in get_bottom_text():
        try:
            driver.find_element_by_xpath("//button[contains(.,'Play')]").click()
        except:
            pass
        time.sleep(.1)

    print("HP Found")
    count = 0

    while 'in progress' not in get_top_text():
        time.sleep(.5)
        count = count + 1

        if count > 20:
            try:
                driver.find_element_by_xpath("//button[contains(.,'Leave')]").click()
                play_again()
            except:
                pass

    print("In progress found")

    players, player_self = get_players()
    print("Hello ", player_self['ID'])

    players = Players()
    chase = 0
    click = False
    
    while players.player_self['HP'] > 5:
        target, i, priori = players.get_target_idx()
            
#             print("Chasing {}".format(target['class']))
#             if chase % 10 == 0 and players.player_self['HP'] > 150:
#                 click = True
            
#             chase = chase + 1

        if len(target) > 0:
            move_mouse(float(target['to_x']),float(target['to_y']))
            target, priori = players.get_player_by_id(i)
        else:
            game_state = driver.execute_script("return window.game_state")
            
            for idx, loot in game_state['loot'].items():
                if loot['t'] != players.player_self['class']:
                    move_mouse(float(loot['pos']['x']),float(loot['pos']['y']))
            
    time.sleep(1)
    spin()
    
def perform_withdraw():
    balance = float(get_bottom_text().split('\n')[1].split(' ')[0])

    if balance > 1:
        driver.find_element_by_css_selector('.btn:nth-child(1)').click()
        time.sleep(.5)
        driver.find_element_by_css_selector('span:nth-child(2) .btn').click()
        driver.find_element_by_xpath("//input[@id='withdraw_amount']").send_keys(str(balance))
        driver.find_element_by_xpath('//span/button').click()
        driver.find_element_by_xpath("//input[@id='refund_address']").send_keys(row['withdraw'])
        driver.find_element_by_xpath("//button[contains(.,'Confirm')]").click()

# %%
perform_login(row)

# %%
while True:
    try:
        with time_limit(240):
#             try:
            play_again()
#             except:
#                 perform_login(row)
    except Exception as e:
        print(str(e))
# Out:
# HP Found
# In progress found
# Hello  4
# HTTPConnectionPool(host='127.0.0.1', port=54866): Max retries exceeded with url: /session/4a83fe04c59ba28d3cce92ea4358934c/execute/sync (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1452934f0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /opt/homebrew/lib/python3.9/site-packages/urllib3/connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# /opt/homebrew/lib/python3.9/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# /opt/homebrew/lib/python3.9/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /opt/homebrew/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# /opt/homebrew/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     393             else:
# --> 394                 conn.request(method, url, **httplib_request_kw)
#     395
#
# /opt/homebrew/lib/python3.9/site-packages/urllib3/connection.py in request(self, method, url, body, headers)
#     238             headers["User-Agent"] = _get_default_user_agent()
# --> 239         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     240
#
# /opt/homebrew/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1284         """Send a complete request to the server."""
# -> 1285         self._send_request(method, url, body, headers, encode_chunked)
#    1286
#
# /opt/homebrew/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1330             body = _encode(body, 'body')
# -> 1331         self.endheaders(body, encode_chunked=encode_chunked)
#    1332
#
# /opt/homebrew/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in endheaders(self, message_body, encode_chunked)
#    1279             raise CannotSendHeader()
# -> 1280         self._send_output(message_body, encode_chunked=encode_chunked)
#    1281
#
# /opt/homebrew/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in _send_output(self, message_body, encode_chunked)
#    1039         del self._buffer[:]
# -> 1040         self.send(msg)
#    1041
#
# /opt/homebrew/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in send(self, data)
#     979             if self.auto_open:
# --> 980                 self.connect()
#     981             else:
#
# /opt/homebrew/lib/python3.9/site-packages/urllib3/connection.py in connect(self)
#     204     def connect(self):
# --> 205         conn = self._new_conn()
#     206         self._prepare_conn(conn)
#
# /opt/homebrew/lib/python3.9/site-packages/urllib3/connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x145294160>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /var/folders/2r/ms7cbbqx6lvcfbw5hl82q7pr0000gn/T/ipykernel_22112/1393217476.py in play_again()
#       3         try:
# ----> 4             driver.find_element_by_xpath("//button[contains(.,'Play')]").click()
#       5             time.sleep(.5)
#
# /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#
# /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#
# /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#
# /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#
# /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#
# /opt/homebrew/lib/python3.9/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      77         else:
# ---> 78             return self.request_encode_body(
#      79                 method, url, fields=fields, headers=headers, **urlopen_kw
#
# /opt/homebrew/lib/python3.9/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# /opt/homebrew/lib/python3.9/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     374         else:
# --> 375             response = conn.urlopen(method, u.request_uri, **kw)
#     376
#
# /opt/homebrew/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# /opt/homebrew/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# /opt/homebrew/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# /opt/homebrew/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /opt/homebrew/lib/python3.9/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=54866): Max retries exceeded with url: /session/4a83fe04c59ba28d3cce92ea4358934c/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x145294160>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/2r/ms7cbbqx6lvcfbw5hl82q7pr0000gn/T/ipykernel_22112/2059496061.py in <module>
#       3         with time_limit(240):
#       4 #             try:
# ----> 5             play_again()
#       6 #             except:
#       7 #                 perform_login(row)
#
# /var/folders/2r/ms7cbbqx6lvcfbw5hl82q7pr0000gn/T/ipykernel_22112/1393217476.py in play_again()
#      12             break
#      13         except:
# ---> 14             time.sleep(.1)
#      15
#      16     while 'HP' not in get_bottom_text():
#
# KeyboardInterrupt:

# %%
#figure out tournament
#captcha

# %%
'label'
'id': 'recaptcha'

# %%
#also don't stop

#withdraw
